 33.40425531914894,
 33.930851063829785,
 34.351063829787236,
 36.09574468085106]

bb_emnist = [11.840425531914894,
 13.143617021276595,
 14.638297872340425,
 16.02127659574468,
 17.1968085106383,
 19.090425531914892,
 19.164893617021278,
 19.02659574468085,
 19.8031914893617,
 21.28723404255319,
 20.68617021276596,
 23.824468085106382,
 22.01595744680851,
 23.585106382978722,
 23.574468085106382,
 25.5,
 25.49468085106383,
 27.19148936170213,
 26.361702127659573,
 27.372340425531913,
 29.893617021276597,
 29.71276595744681,
 29.49468085106383,
 31.06382978723404,
 30.46808510638298,
 33.70744680851064,
 32.723404255319146]

# %%
# batch 20, reps=4
# [56.23, 61.58, 68.37, 71.21, 75.78, 83.07, 84.06, 84.09]

# %%
lbb15 = [66.63,
 63.12,
 66.98,
 70.25,
 68.34,
 67.08,
 76.16,
 81.12,
 80.93,
 82.49,
 85.7,
 86.22,
 86.54,
 84.93,
 85.88,
 87.64,
 88.2,
 88.84,
 89.49,
 90.07,
 89.59,
 89.19,
 90.44,
 91.04,
 90.91,
 91.5,
 91.97]

lbb110 = [66.63,
 65.28,
 71.23,
 72.55,
 76.22,
 78.34,
 85.8,
 85.98,
 85.72,
 87.42,
 87.96,
 89.21,
 90.82,
 90.24]

lbb45 = [56.23,
 61.56,
 64.93,
 65.2,
 70.6,
 74.1,
 75.65,
 78.22,
 81.65,
 83.91,
 85.51,
 85.92,
 86.02,
 84.85,
 88.06,
 89.22,
 87.42,
 88.13,
 89.0,
 90.02,
 87.64,
 89.52,
 90.37,
 89.79,
 91.21,
 91.55,
 90.32]

lbb410 = [56.23,
 64.97,
 65.78,
 77.12,
 75.46,
 78.52,
 82.45,
 80.91,
 87.24,
 86.85,
 88.21,
 89.24,
 89.49,
 89.19]

# %%
# 0 reps, start 100 end 150
# bald_accs = [85.06, 87.8, 88.4, 89.55, 88.17, 88.78, 89.26, 91.12, 91.11, 91.91, 92.31]

# %%
# 4 rep, batch 10
# lbb410 = [56.23,
#  67.49,
#  67.34,
#  66.76,
#  67.87,
#  68.64,
#  70.06,
#  73.02,
#  70.27,
#  74.29,
#  76.27,
#  78.28,
#  78.81,
#  79.13]

# %%
# 0 rep, batch 5
# 0 rep, batch 10
bald010 = [66.63,
 65.01,
 74.26,
 76.37,
 78.61,
 80.54,
 83.73,
 84.82,
 87.26,
 87.36,
 88.4,
 88.39,
 91.6,
 90.73]
bb010 = [66.63,
 71.19,
 70.62,
 78.59,
 79.32,
 78.93,
 82.71,
 86.91,
 84.98,
 88.03,
 89.43,
 89.1,
 91.49,
 92.11]
lbb010 = [66.63,
 68.06,
 73.81,
 78.45,
 78.86,
 77.3,
 82.43,
 83.06,
 84.13,
 85.62,
 87.15,
 87.59,
 88.06,
 88.78]

# %%
# random
# 0 rep, batch 5
random05 = [63.51,
 63.1,
 65.0,
 67.0,
 73.39,
 76.98,
 73.58,
 78.76,
 77.33,
 78.42,
 78.12,
 82.04,
 81.41,
 80.79,
 83.71,
 84.47,
 86.04,
 86.2,
 86.03,
 86.56,
 85.67,
 87.84,
 89.0,
 87.5,
 88.02,
 87.61,
 89.07]
# 0 rep, batch 10
random010 = [63.51,
 68.66,
 79.08,
 79.04,
 78.91,
 83.52,
 83.5,
 83.02,
 85.66,
 84.58,
 86.81,
 87.1,
 87.79,
 88.46]
# 1 rep, batch 5
random15 = [63.51,
 63.1,
 65.0,
 67.0,
 73.39,
 76.98,
 73.58,
 78.76,
 77.33,
 78.42,
 78.12,
 82.04,
 81.41,
 80.79,
 83.71,
 84.47,
 86.04,
 86.2,
 86.03,
 86.56,
 85.67,
 87.84,
 89.0,
 87.5,
 88.02,
 87.61,
 89.07]
# 1 rep, batch 10
random110 = [63.51,
 68.66,
 79.08,
 79.04,
 78.91,
 83.52,
 83.5,
 83.02,
 85.66,
 84.58,
 86.81,
 87.1,
 87.79,
 88.46]
# 4 rep, batch 5
random45 = [56.02,
 59.41,
 60.08,
 62.14,
 65.11,
 71.61,
 74.46,
 78.1,
 78.48,
 79.59,
 83.55,
 80.61,
 83.15,
 81.93,
 83.54,
 85.45,
 84.05,
 85.68,
 87.09,
 87.41,
 87.03,
 86.7,
 86.69,
 87.43,
 89.16,
 88.77,
 87.45]
# 4 rep, batch 10
random410 = [56.02,
 65.99,
 74.79,
 80.14,
 77.86,
 81.39,
 78.78,
 81.83,
 83.64,
 85.94,
 86.16,
 85.0,
 85.97,
 85.06]

# %%
# RMNIST, number of rep-s = 1, batch 5
test_accs_bb = [
    64.75,
    68.19,
    69.0,
    65.95,
    73.85,
    73.78,
    76.59,
    79.4,
    78.45,
    79.99,
    83.43,
    88.24,
    89.86,
    87.31,
    88.02,
    88.99,
    89.43,
    90.39,
    89.94,
    88.93,
    89.93,
    92.08,
    91.15,
    91.77,
    89.94,
    91.11,
    91.43,
]

test_accs_lbb1 = [62.66,
     63.55,
     62.47,
     68.19,
     75.31,
     79.12,
     77.11,
     79.72,
     79.42,
     78.81,
     78.53,
     81.83,
     84.57,
     83.12,
     83.93,
     83.86,
     83.92,
     84.76,
     85.7,
     87.54,
     88.09,
     88.58,
     87.71,
     87.92,
     88.58,
     88.92,
     88.66,
]

test_accs_lbb2 = [61.76,
 60.51,
 66.17,
 68.88,
 71.93,
 74.63,
 73.54,
 73.16,
 72.43,
 79.26,
 81.64,
 79.49,
 78.77,
 81.88,
 82.63,
 82.56,
 82.28,
 82.81,
 82.98,
 82.66,
 82.25,
 82.92,
 82.11,
 82.28,
 84.43,
 83.63,
 84.72]
# last good
test_accs_lbb3 = [59.6,
 61.51,
 67.97,
 74.64,
 74.66,
 77.24,
 80.06,
 81.96,
 79.58,
 81.6,
 81.67,
 82.8,
 80.94,
 83.04,
 81.43,
 81.37,
 81.06,
 81.95,
 82.43,
 82.45,
 83.22,
 85.06,
 82.62,
 83.67,
 85.59,
 85.08,
 84.52]

test_accs_lbb31 = [65.51,
 66.9,
 62.88,
 68.79,
 69.23,
 72.01,
 76.17,
 77.67,
 77.74,
 76.64,
 77.19,
 78.37,
 77.02,
 78.06,
 79.7,
 78.45,
 82.79,
 81.24,
 81.52,
 83.8,
 82.9,
 85.27,
 85.21,
 85.44,
 85.95,
 85.2,
 86.66]

test_accs_lbb4_slow = [57.91,
 62.57,
 68.64,
 74.28,
 74.36,
 81.17,
 82.52,
 82.03,
 77.66,
 83.6,
 84.5,
 84.12,
 86.72,
 86.8,
 88.4,
 86.98,
 86.36,
 86.66,
 86.91,
 88.67,
 88.48,
 89.39,
 88.82,
 89.07,
 89.38,
 89.28,
 89.54]

test_accs_lbb4_slow = [57.91,
 62.57,
 68.64,
 74.28,
 74.36,
 81.17,
 82.52,
 82.03,
 77.66,
 83.6,
 84.5,
 84.12,
 86.72,
 86.8,
 88.4,
 86.98,
 86.36,
 86.66,
 86.91,
 88.67,
 88.48,
 89.39,
 88.82,
 89.07,
 89.38,
 89.28,
 89.54]
###
test_accs_lbb5_slow = [59.63,
 61.38,
 61.83,
 68.12,
 69.48,
 68.96,
 72.4,
 70.7,
 73.74,
 75.68,
 78.3,
 77.77,
 79.06,
 82.22,
 81.59,
 80.36,
 82.26,
 85.98,
 84.61,
 86.4,
 87.85,
 88.29,
 86.65,
 90.27,
 90.51,
 89.82,
 88.77]

test_accs_lbb52_slow = [57.1,
 59.44,
 65.32,
 67.16,
 73.31,
 76.28,
 76.8,
 76.51,
 78.22,
 80.85,
 81.82,
 80.77,
 83.16,
 82.29,
 83.95,
 84.41,
 87.33,
 87.52,
 87.49,
 86.11,
 88.03,
 88.74,
 88.99,
 87.6,
 90.18,
 88.12,
 90.17]
###
test_accs_bald=[62.69,
 69.11,
 75.98,
 73.79,
 75.67,
 78.65,
 80.06,
 80.23,
 80.64,
 80.9,
 82.24,
 84.49,
 84.55,
 84.96,
 86.21,
 86.58,
 87.85,
 89.3,
 89.53,
 89.35,
 89.81,
 90.03,
 89.88,
 90.96,
 92.14,
 93.21,
 92.11]

# %%
# RMNIST, number of rep-s = 1, batch 10
test_accs_b10 = [66.16,
 67.6,
 69.82,
 72.47,
 71.86,
 79.88,
 81.46,
 81.17,
 85.12,
 86.05,
 85.55,
 88.5,
 86.69,
 89.43]
test_accs_bb10 = [64.18,
 70.83,
 77.95,
 80.2,
 82.41,
 79.55,
 83.35,
 84.99,
 89.56,
 89.52,
 89.49,
 90.2,
 91.06,
 91.4]
test_accs_lbb10 = [67.08,
 73.79,
 75.21,
 76.72,
 77.3,
 78.95,
 81.78,
 84.38,
 83.0,
 84.93,
 86.53,
 86.36,
 88.02,
 91.42]

# %%
# RMNIST, rep = 4, batch 5

test_accs4_b5 = [63.74,
 64.77,
 63.78,
 66.57,
 67.89,
 67.58,
 69.85,
 64.31,
 69.46,
 69.62,
 68.3,
 71.48,
 65.71,
 72.06,
 75.66,
 74.67,
 72.86,
 76.44,
 76.43,
 80.59,
 79.78,
 78.91,
 78.52,
 79.2,
 79.86,
 75.84,
 81.2] # 20 sec # can take [9, 9, 9, 9, 9]
# scores can be [1.3700689427997434, 1.3700689427997434, 1.3700689427997434, 1.3700689427997434, 1.3381412600750857]
# oft sit-n: 
# Scores:  [1.2813781095778696, 1.2813781095778696, 1.2813781095778696, 1.2813781095778696, 1.2697754527308138]
# Labels:  tensor([8, 8, 8, 8, 8])
test_accs4_bb5 = [64.63,
 66.61,
 68.86,
 75.15,
 78.7,
 79.84,
 81.43,
 82.02,
 85.72,
 83.67,
 88.4,
 88.01,
 89.21,
 89.42,
 88.98,
 89.07,
 90.84,
 90.55,
 90.44,
 91.9,
 91.04,
 91.65,
 91.4,
 92.03,
 92.74,
 92.48,
 92.72] # 70 sec
test_accs4_lbb5 = [65.37,
 66.87,
 69.01,
 66.13,
 71.85,
 72.77,
 68.97,
 70.64,
 71.03,
 68.81,
 78.61,
 79.61,
 78.8,
 80.68,
 78.74,
 78.32,
 76.68,
 78.68,
 79.06,
 81.54,
 81.0,
 81.9,
 80.92,
 81.9,
 80.89,
 82.04,
 84.24] # 540 sec

test_accs4_lbb51 = [59.91,
 63.08,
 67.98,
 68.95,
 67.69,
 70.64,
 69.58,
 70.67,
 67.65,
 68.38,
 71.14,
 72.57,
 74.21,
 74.93,
 76.02,
 74.3,
 75.55,
 74.96,
 78.79,
 80.96,
 77.79,
 74.76,
 80.41,
 79.55,
 80.95,
 82.77,
 81.96] # final

# %%
# RMNIST, rep 4, batch 10
test_accs4_b10 = [61.19,
 62.25,
 67.02,
 67.0,
 70.44,
 67.22,
 70.41,
 69.79,
 72.58,
 71.07,
 72.1,
 72.56,
 77.73,
 76.29] # 20 sec
test_accs4_bb10 = [68.48,
 74.95,
 75.58,
 81.8,
 86.25,
 87.83,
 87.75,
 89.64,
 89.44,
 89.72,
 89.97,
 89.7,
 90.59,
 89.82] # 3311.62 sec
test_accs4_lbb10 = []

# %%
# # ensembles 150

# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), ens_bb_emnist, 'g', label='BB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), ens_lbb_emnist, 'b', label='LBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), ens_bald_emnist, 'k', label='BALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), ens_rand_emnist, 'c', label='Rand', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, EMNIST, batch 5")
# # plt.hlines(90, 20, 150, linestyles="dashed", color="r")
# plt.legend()
# plt.savefig('emnist-batch5.svg')
# plt.show()

# %%
random_seed = 42
dataset = "EMNIST"
uns_type = "ENS"
num_initial_samples = 20
max_training_samples = 250
acquisition_batch_size = 5

d = {'Number of samples': np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size),
     'BB': bb_250,
     'LBB': lbb_250,
     'BALD': bald_250,
     'Rand': rand_250
    }
df = pd.DataFrame(data=d)
df.to_csv('results/' + uns_type + "/" + dataset + "/" + str(acquisition_batch_size) + "/" + str(random_seed) + ".csv", sep=',', index=False)

# %%
# EMNIST 50

lbb = [14.319148936170214,
 23.319148936170212,
 32.648936170212764,
 39.02127659574468,
 46.45744680851064,
 53.17553191489362,
 56.005319148936174,
 58.202127659574465,
 60.755319148936174,
 62.87765957446808,
 64.82446808510639,
 66.16489361702128,
 67.04787234042553,
 68.07978723404256,
 68.91489361702128,
 69.65425531914893,
 70.26595744680851,
 71.82978723404256,
 72.98404255319149,
 73.73936170212765,
 74.22872340425532]

pbald = [14.319148936170214, 27.420212765957448, 36.462765957446805, 43.04255319148936, 51.02127659574468, 
         55.159574468085104, 59.29255319148936, 61.83510638297872, 64.29787234042553, 66.92553191489361,
         67.83510638297872, 70.06914893617021, 71.40957446808511, 72.11702127659575, 73.72340425531915,
         74.09042553191489, 74.96808510638297, 75.44680851063829, 76.05319148936171, 76.46808510638297,
         77.31914893617021]

bald = pd.read_csv('results/ENS/EMNIST/50/42.csv')['BALD']

rand = [14.319148936170214,
 26.425531914893618,
 32.07446808510638,
 39.40425531914894,
 45.87765957446808,
 50.090425531914896,
 52.33510638297872,
 55.712765957446805,
 57.16489361702128,
 59.07446808510638,
 60.909574468085104,
 61.898936170212764,
 62.851063829787236,
 64.70744680851064,
 65.92021276595744,
 67.27659574468085,
 68.03191489361703,
 68.93085106382979,
 70.51063829787235,
 70.42021276595744,
 71.5372340425532]

# %%
# MNIST 50
# BB [66.32, 85.0, 91.83, 94.07, 95.3, 96.13, 97.15]
# BALD [66.32, 82.6, 86.21, 88.37, 91.85, 93.46, 95.52]
# PLBB # [66.32, 85.93, 90.79, 93.38, 95.01, 95.91, 96.76]
# Rand # [66.32, 84.27, 89.02, 91.34, 93.06, 93.88, 94.32]
# PBALD # [66.32, 85.53, 91.18, 93.33, 95.57, 96.13, 97.52]

# %%
# setting 3 imgs in a row
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85
# linewidth=7.0

# %%
# # BB
# [66.32,
#   69.87,
#   71.7,
#   74.28,
#   76.86,
#   80.44,
#   82.87,
#   85.15,
#   84.39,
#   86.92,
#   85.93,
#   87.3,
#   87.86,
#   88.53,
#   89.36,
#   90.43,
#   90.84,
#   89.87,
#   90.26,
#   90.01,
#   90.93,
#   91.38,
#   91.43,
#   91.96,
#   92.25,
#   92.79,
#   93.47,
#   94.28,
#   94.18,
#   94.97,
#   94.17,
#   94.92,
#   95.29,
#   95.68,
#   95.36,
#   95.77,
#   95.92,
#   95.9,
#   96.05,
#   96.12,
#   96.11,
#   95.49,
#   95.75,
#   96.06,
#   96.27,
#   96.44,
#   96.54,
#   96.34,
#   96.42,
#   96.61,
#   96.36,
#   96.47,
#   96.71,
#   96.45,
#   96.54,
#   96.63,
#   96.52],

# LBB
# [66.32,
#   68.6,
#   72.36,
#   75.61,
#   77.06,
#   78.09,
#   80.04,
#   81.49,
#   81.35,
#   84.18,
#   84.29,
#   85.42,
#   86.71,
#   89.84,
#   90.82,
#   91.49,
#   92.0,
#   92.09,
#   92.54,
#   92.95,
#   93.39,
#   93.65,
#   93.15,
#   94.25,
#   94.32,
#   94.34,
#   94.32,
#   94.68,
#   94.77,
#   94.7,
#   94.79,
#   94.8,
#   95.48,
#   95.23,
#   95.56,
#   95.59,
#   95.39,
#   95.88,
#   96.12,
#   95.95,
#   96.15,
#   96.14,
#   96.42,
#   96.45,
#   96.61,
#   96.82,
#   96.73,
#   96.65,
#   96.79,
#   96.94,
#   96.88,
#   97.16,
#   97.19,
#   97.28,
#   97.21,
#   97.24,
#   97.31]

# %%
# 'BB': [66.32,
#   74.0,
#   80.86,
#   81.41,
#   77.81,
#   80.26,
#   84.1,
#   86.84,
#   88.44,
#   89.34,
#   90.17,
#   91.02,
#   92.24,
#   92.53,
#   93.97,
#   94.43,
#   94.65,
#   94.89,
#   95.58,
#   95.81,
#   96.56,
#   96.48,
#   96.98,
#   96.96,
#   97.18,
#   97.63,
#   97.32,
#   97.39,
#   97.69],
#  'LBB': [65.68,
#   72.71,
#   77.14,
#   81.87,
#   81.24,
#   80.85,
#   86.09,
#   88.04,
#   88.93,
#   90.87,
#   91.27,
#   91.99,
#   92.95,
#   93.29,
#   93.76,
#   94.24,
#   94.97,
#   95.35,
#   95.4,
#   96.07,
#   96.17,
#   96.57,
#   96.49,
#   96.85,
#   96.77,
#   97.19,
#   97.06,
#   97.21,
#   97.52],
#  'PLBB': [66.09,
#   77.67,
#   80.82,
#   85.21,
#   83.97,
#   88.25,
#   88.9,
#   89.9,
#   91.73,
#   92.61,
#   93.31,
#   94.0,
#   94.97,
#   94.85,
#   95.15,
#   95.44,
#   95.9,
#   95.89,
#   96.41,
#   96.47,
#   96.69,
#   96.5,
#   96.87,
#   96.86,
#   97.26,
#   97.33,
#   97.37,
#   97.27,
#   97.45],

# %%
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# random_seed = 42
# dataset = "MNIST"
# uns_type = "MC"
# num_initial_samples = 20
# max_training_samples = 150
# acquisition_batch_size = 5

# df = pd.read_csv("results/" + uns_type + "/" + dataset + "/" + str(acquisition_batch_size) + "/" + str(random_seed) + ".csv")

# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BB'], 'g', label='BB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['LBB'], 'b', label='LBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BALD'], 'k', label='BALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['Rand'], 'c', label='Rand', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, MNIST, batch 5")
# plt.hlines(90, 20, 150, linestyles="dashed", color="r")
# plt.legend()
# plt.savefig('pics/mnist-batch5.svg')
# plt.show()

# %%
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# random_seed = 42
# dataset = "MNIST"
# uns_type = "MC"
# num_initial_samples = 20
# max_training_samples = 150
# acquisition_batch_size = 10

# df = pd.read_csv('results/' + uns_type + "/" + dataset + "/" + str(acquisition_batch_size) + "/" + str(random_seed) + ".csv")

# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BB'], 'g', label='BB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['LBB'], 'b', label='LBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BALD'], 'k', label='BALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['Rand'], 'c', label='Rand', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, MNIST, batch 10")
# plt.hlines(90, 20, 150, linestyles="dashed", color="r")
# plt.legend()
# plt.savefig('pics/mnist-batch10.svg')
# plt.show()

# %%
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# random_seed = 42
# dataset = "RMNIST4"
# uns_type = "MC"
# num_initial_samples = 20
# max_training_samples = 150
# acquisition_batch_size = 5

# df = pd.read_csv('results/' + uns_type + "/" + dataset + "/" + str(acquisition_batch_size) + "/" + str(random_seed) + ".csv")

# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BB'], 'g', label='BB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['LBB'], 'b', label='LBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BALD'], 'k', label='BALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['Rand'], 'c', label='Rand', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, RMNIST, batch 5")
# plt.hlines(90, 20, 150, linestyles="dashed", color="r")
# plt.legend()
# plt.savefig('pics/rmnist-batch5.svg')
# plt.show()

# %%
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# random_seed = 42
# dataset = "RMNIST4"
# uns_type = "MC"
# num_initial_samples = 20
# max_training_samples = 150
# acquisition_batch_size = 10

# df = pd.read_csv('results/' + uns_type + "/" + dataset + "/" + str(acquisition_batch_size) + "/" + str(random_seed) + ".csv")

# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BB'], 'g', label='BB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['LBB'], 'b', label='LBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BALD'], 'k', label='BALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['Rand'], 'c', label='Rand', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, RMNIST, batch 10")
# plt.hlines(90, 20, 150, linestyles="dashed", color="r")
# plt.legend()
# plt.savefig('pics/rmnist-batch10.svg')
# plt.show()

# %%
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# random_seed = 42
# dataset = "EMNIST"
# uns_type = "ENS"
# num_initial_samples = 20
# max_training_samples = 250
# acquisition_batch_size = 5

# df = pd.read_csv('results/' + uns_type + "/" + dataset + "/" + str(acquisition_batch_size) + "/" + str(random_seed) + ".csv")

# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BB'], 'g', label='BB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['LBB'], 'b', label='LBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['BALD'], 'k', label='BALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 1, acquisition_batch_size), df['Rand'], 'c', label='Rand', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, EMNIST, batch 5")
# plt.legend()
# plt.savefig('pics/emnist-batch5-250.svg')
# plt.show()

# %%
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# random_seed = 42
# dataset = "EMNIST"
# uns_type = "ENS"
# num_initial_samples = 20
# max_training_samples = 1000
# acquisition_batch_size = 50

# df = pd.read_csv('results/' + uns_type + "/" + dataset + "/" + str(acquisition_batch_size) + "/" + str(random_seed) + ".csv")

# plt.plot(np.arange(num_initial_samples, max_training_samples + 21, acquisition_batch_size), df['PBALD'], 'm', label='PBALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 21, acquisition_batch_size), df['PLBB'], 'r', label='PLBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 21, acquisition_batch_size), df['BALD'], 'k', label='BALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 21, acquisition_batch_size), df['Rand'], 'c', label='Rand', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, EMNIST, batch 50")
# plt.legend()
# plt.savefig('pics/ens_emnist_batch50.svg')
# plt.show()

# %%
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# random_seed = 42
# dataset = "MNIST"
# uns_type = "ENS"
# num_initial_samples = 20
# max_training_samples = 300
# acquisition_batch_size = 50

# df = pd.read_csv('results/' + uns_type + "/" + dataset + "/" + str(acquisition_batch_size) + "/" + str(random_seed) + ".csv")

# plt.plot(np.arange(num_initial_samples, max_training_samples + 21, acquisition_batch_size), df['PBALD'], 'm', label='PBALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 21, acquisition_batch_size), df['BB'], 'g', label='BB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 21, acquisition_batch_size), df['PLBB'], 'r', label='PLBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 21, acquisition_batch_size), df['BALD'], 'k', label='BALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + 21, acquisition_batch_size), df['Rand'], 'c', label='Rand', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, MNIST, batch 50")
# plt.legend()
# plt.savefig('pics/ens_mnist_batch50.svg')
# plt.show()

# %%
bb = [66.32,
  74.0,
  80.86,
  81.41,
  77.81,
  80.26,
  84.1,
  86.84,
  88.44,
  89.34,
  90.17,
  91.02,
  92.24,
  92.53,
  93.97,
  94.43,
  94.65,
  94.89,
  95.58,
  95.81,
  96.56,
  96.48,
  96.98,
  96.96,
  97.18,
  97.63,
  97.32,
  97.39,
  97.69],
lbb = [65.68,
  72.71,
  77.14,
  81.87,
  81.24,
  80.85,
  86.09,
  88.04,
  88.93,
  90.87,
  91.27,
  91.99,
  92.95,
  93.29,
  93.76,
  94.24,
  94.97,
  95.35,
  95.4,
  96.07,
  96.17,
  96.57,
  96.49,
  96.85,
  96.77,
  97.19,
  97.06,
  97.21,
  97.52],
plbb = [66.09,
  77.67,
  80.82,
  85.21,
  83.97,
  88.25,
  88.9,
  89.9,
  91.73,
  92.61,
  93.31,
  94.0,
  94.97,
  94.85,
  95.15,
  95.44,
  95.9,
  95.89,
  96.41,
  96.47,
  96.69,
  96.5,
  96.87,
  96.86,
  97.26,
  97.33,
  97.37,
  97.27,
  97.45],

# %%
random_seed = 42
random.seed(random_seed)
np.random.seed(random_seed)
torch.manual_seed(random_seed)
torch.backends.cudnn.deterministic = True

max_training_samples = 300
acquisition_batch_size = 10 # initially: 5
num_inference_samples = 100
num_test_inference_samples = 5
num_samples = 100000

test_batch_size = 512
batch_size = 64
scoring_batch_size = 128
training_iterations = 4096 * 6

T = 10
num_initial_samples = 30

# %%
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# bald = pd.read_csv('results/ENS/MNIST/10/BALD42.csv')
# pbald = pd.read_csv('results/ENS/MNIST/10/PBALD42.csv')

# plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], pbald['Test accuracy'][1:], 'm', label='PBALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], bb[0][1:-1], 'g', label='BB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], lbb[0][1:-1], 'b', label='LBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], plbb[0][1:-1], 'r', label='PLBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], bald['Test accuracy'][1:], 'k', label='BALD', linewidth=7.0)
# # plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size), df['Rand'], 'c', label='Rand', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, MNIST, batch 10")
# plt.legend()
# plt.savefig('pics/ens_mnist_batch10.svg')
# plt.show()

# %%
plt.figure(figsize=(20, 15))
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['font.size'] = 85

random_seed = 42
dataset = "CIFAR100"
uns_type = "ENS"
num_initial_samples = 200
max_training_samples = 4000
acquisition_batch_size = 50

bald = pd.read_csv('results/ENS/CIFAR100/50/BALD42.csv')
plbb = pd.read_csv('results/ENS/CIFAR100/50/PLBB42.csv')
rand = pd.read_csv('results/ENS/CIFAR100/50/Rand42.csv')

plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], plbb['Test accuracy'], 'r', label='PLBB', linewidth=7.0)
plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], bald['Test accuracy'], 'k', label='BALD', linewidth=7.0)
plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], rand['Test accuracy'], 'c', label='Rand', linewidth=7.0)
plt.xlabel("Number of training samples")
plt.ylabel("Accuracy")
plt.title("Accuracy, CIFAR100, batch 50")
plt.legend()
plt.savefig('pics/ens_cifar100_batch50.svg')
plt.show()

# %%
# plt.figure(figsize=(20, 15))
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.size'] = 85

# random_seed = 42
# dataset = "EMNIST"
# uns_type = "ENS"
# num_initial_samples = 20
# max_training_samples = 1000
# acquisition_batch_size = 10

# bald = pd.read_csv('results/ENS/EMNIST/10/BALD42.csv')
# plbb = pd.read_csv('results/ENS/EMNIST/10/PLBB42.csv')
# lbb = pd.read_csv('results/ENS/EMNIST/10/LBB42.csv')

# plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], plbb['Test accuracy'], 'r', label='PLBB', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], bald['Test accuracy'], 'k', label='BALD', linewidth=7.0)
# plt.plot(np.arange(num_initial_samples, max_training_samples + acquisition_batch_size - 1, acquisition_batch_size)[1:], lbb['Test accuracy'], 'b', label='LBB', linewidth=7.0)
# plt.xlabel("Number of training samples")
# plt.ylabel("Accuracy")
# plt.title("Accuracy, EMNIST, batch 10")
# plt.legend()
# plt.savefig('pics/ens_emnist_batch10.svg')
# plt.show()
